# %% [markdown]
# ### RPA with Python using PyAutoGui

# %%
import subprocess
import pyautogui
import time

# %%
sap_gui = subprocess.Popen("C:\Program Files (x86)\SAP\FrontEnd\SAPgui\saplgpad.exe")

# %%
# wait 3 seconds for the program to load
time.sleep(3)

# %%
# double click
pyautogui.doubleClick()
# right click
pyautogui.click(button='right')
# hot key with ctrl + f9 (shortcut for SAP command)
pyautogui.hotkey('ctrl', 'f9')
# press tab to shift to the next input field
pyautogui.press('tab')
pyautogui.hotkey('ctrl', 'c')  # ctrl-c to cop
pyautogui.typewrite('Hello world!\n', interval=.5)  # useful for entering text, newline is Enter
# Out:
# Address(city_name=None, country_code=None, country_name=None, empty=True, line1=None, line2=None, postal_code=None, subdivision_code=None, subdivision_name=None, subdivision_type_id=None, subdivision_type_name=None, valid=False)

# %%
hello = pyautogui.prompt('This lets the user type in a string and press OK.')

# %%
pyautogui.screenshot('screenshot1.png')  # returns a Pillow/PIL Image object, and saves it to a fileturns a Pillow/PIL Image object
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x79A5270>

# %%
pyautogui.locateOnScreen('looksLikeThis.png')

# %%
username_field_location = pyautogui.locateOnScreen('username_field.png')
pyautogui.moveTo(username_field_location)
pyautogui.click()
# type the username in the field that we just clicked
pyautogui.typewrite('username')
# move (relative from the current cursor position) to below 50 pixel
pyautogui.moveRel(0, 50)
pyautogui.click()
# type the password
pyautogui.typewrite('password')
pyautogui.press('enter')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13384/3047702544.py in <module>
# ----> 1 username_field_location = pyautogui.locateOnScreen('username_field.png')
#       2 pyautogui.moveTo(username_field_location)
#       3 pyautogui.click()
#       4 # type the username in the field that we just clicked
#       5 pyautogui.typewrite(username)
#
# c:\users\nelsonr\pycharmprojects\pythonproject1\venv\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
#     176         except pyscreeze.ImageNotFoundException:
#     177             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#
# ...
